# %% [markdown]
# <a href="https://colab.research.google.com/github/mayanksreal/marks-evaluation/blob/main/deep_neural_nets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Dependencies

# %%
from tensorflow.keras.datasets import mnist # type:ignore
from tensorflow.keras.layers import Flatten, Dense, Dropout, Input # type:ignore
from tensorflow.keras.models import Sequential # type:ignore
from matplotlib import pyplot as plt

# %% [markdown]
# ### Load Dataset

# %%
(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train/255.0, x_test/255.0

# %% [markdown]
# ## Simple Neural Network
#
# Let's try a single-layered neural network

# %% [markdown]
# ### Building and training

# %%
model = Sequential()


model.add(Input(shape=(28,28)))
model.add(Flatten())

model.add(Dense(64, 'relu'))
model.add(Dropout(0.2))

model.add(Dense(10, 'softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=20, validation_split=0.2)
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8085 - loss: 0.6449 - val_accuracy: 0.9450 - val_loss: 0.1901
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9343 - loss: 0.2236 - val_accuracy: 0.9601 - val_loss: 0.1414
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9507 - loss: 0.1703 - val_accuracy: 0.9640 - val_loss: 0.1228
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9550 - loss: 0.1468 - val_accuracy: 0.9666 - val_loss: 0.1193
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9609 - loss: 0.1268 - val_accuracy: 0.9682 - val_loss: 0.1064
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9634 - loss: 0.1143 - val_accuracy: 0.9690 - val_loss: 0.1033
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9687 - loss: 0.1015 - val_accuracy: 0.9706 - val_loss: 0.1044
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9688 - loss: 0.0994 - val_accuracy: 0.9703 - val_loss: 0.1013
# Epoch 9/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9711 - loss: 0.0880 - val_accuracy: 0.9728 - val_loss: 0.0958
# Epoch 10/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9712 - loss: 0.0877 - val_accuracy: 0.9728 - val_loss: 0.0957
# Epoch 11/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9738 - loss: 0.0813 - val_accuracy: 0.9728 - val_loss: 0.0969
# Epoch 12/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9746 - loss: 0.0779 - val_accuracy: 0.9743 - val_loss: 0.0932
# Epoch 13/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9771 - loss: 0.0729 - val_accuracy: 0.9755 - val_loss: 0.0891
# Epoch 14/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9776 - loss: 0.0678 - val_accuracy: 0.9732 - val_loss: 0.0942
# Epoch 15/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9774 - loss: 0.0667 - val_accuracy: 0.9743 - val_loss: 0.0967
# Epoch 16/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9790 - loss: 0.0625 - val_accuracy: 0.9746 - val_loss: 0.0965
# Epoch 17/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9783 - loss: 0.0645 - val_accuracy: 0.9740 - val_loss: 0.1020
# Epoch 18/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9779 - loss: 0.0633 - val_accuracy: 0.9737 - val_loss: 0.0999
# Epoch 19/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9807 - loss: 0.0600 - val_accuracy: 0.9753 - val_loss: 0.0989
# Epoch 20/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9813 - loss: 0.0565 - val_accuracy: 0.9758 - val_loss: 0.0919

# %% [markdown]
# ### Results

# %%
plt.plot(history.history['accuracy'][0:], label='Train Accuracy')
plt.plot(history.history['val_accuracy'][0:], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')
plt.show()

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9696 - loss: 0.1180
# [0.09707139432430267, 0.9742000102996826]

# %% [markdown]
# We can see from the plot that single-layer model begins to overfit after only 10 epochs, giving test accuracy of only 97%.

# %% [markdown]
# ## Deep Neural Network
#
# Let's try a deep neural network with several connected layers

# %% [markdown]
# ### Building and training

# %%
model = Sequential()


model.add(Input(shape=(28,28)))
model.add(Flatten())

#Three fully connected layers

model.add(Dense(64, 'relu'))
model.add(Dropout(0.2))

model.add(Dense(64, 'relu'))
model.add(Dropout(0.2))

model.add(Dense(64, 'relu'))
model.add(Dropout(0.2))

model.add(Dense(10, 'softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=25, validation_split=0.2)
# Out:
# Epoch 1/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7336 - loss: 0.8098 - val_accuracy: 0.9475 - val_loss: 0.1749
# Epoch 2/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9222 - loss: 0.2675 - val_accuracy: 0.9563 - val_loss: 0.1465
# Epoch 3/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9362 - loss: 0.2135 - val_accuracy: 0.9628 - val_loss: 0.1280
# Epoch 4/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9482 - loss: 0.1740 - val_accuracy: 0.9632 - val_loss: 0.1219
# Epoch 5/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9523 - loss: 0.1569 - val_accuracy: 0.9657 - val_loss: 0.1227
# Epoch 6/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9564 - loss: 0.1472 - val_accuracy: 0.9658 - val_loss: 0.1212
# Epoch 7/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9594 - loss: 0.1408 - val_accuracy: 0.9690 - val_loss: 0.1095
# Epoch 8/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9643 - loss: 0.1237 - val_accuracy: 0.9695 - val_loss: 0.1099
# Epoch 9/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9628 - loss: 0.1269 - val_accuracy: 0.9707 - val_loss: 0.1052
# Epoch 10/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9654 - loss: 0.1164 - val_accuracy: 0.9686 - val_loss: 0.1079
# Epoch 11/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9661 - loss: 0.1158 - val_accuracy: 0.9688 - val_loss: 0.1092
# Epoch 12/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9642 - loss: 0.1147 - val_accuracy: 0.9723 - val_loss: 0.1030
# Epoch 13/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9709 - loss: 0.1008 - val_accuracy: 0.9706 - val_loss: 0.1033
# Epoch 14/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9703 - loss: 0.0978 - val_accuracy: 0.9722 - val_loss: 0.1059
# Epoch 15/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9709 - loss: 0.0962 - val_accuracy: 0.9727 - val_loss: 0.0999
# Epoch 16/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9708 - loss: 0.0967 - val_accuracy: 0.9728 - val_loss: 0.1054
# Epoch 17/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9705 - loss: 0.0979 - val_accuracy: 0.9723 - val_loss: 0.1009
# Epoch 18/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9725 - loss: 0.0917 - val_accuracy: 0.9713 - val_loss: 0.1065
# Epoch 19/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9726 - loss: 0.0878 - val_accuracy: 0.9733 - val_loss: 0.0963
# Epoch 20/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9716 - loss: 0.0939 - val_accuracy: 0.9722 - val_loss: 0.0996
# Epoch 21/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9736 - loss: 0.0866 - val_accuracy: 0.9738 - val_loss: 0.1001
# Epoch 22/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9737 - loss: 0.0864 - val_accuracy: 0.9722 - val_loss: 0.1067
# Epoch 23/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9744 - loss: 0.0840 - val_accuracy: 0.9716 - val_loss: 0.1042
# Epoch 24/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9749 - loss: 0.0863 - val_accuracy: 0.9726 - val_loss: 0.0999
# Epoch 25/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9755 - loss: 0.0780 - val_accuracy: 0.9734 - val_loss: 0.1025

# %% [markdown]
# ### Results

# %%
plt.plot(history.history['accuracy'][0:], label='Train Accuracy')
plt.plot(history.history['val_accuracy'][0:], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')
plt.show()

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9686 - loss: 0.1145
# [0.10163957625627518, 0.9729999899864197]

# %% [markdown]
# While the model took much longer to train and did not overfit until about 15 epochs, there was little to no improvement in test accuracy.

# %% [markdown]
# ## Funneling Deep Neural Networks
# Let's try a funneling deep neural network with increasingly smaller units in each dense layer.

# %% [markdown]
# ### Building and training

# %%
model = Sequential()


model.add(Input(shape=(28,28)))
model.add(Flatten())

#Three fully connected layers

model.add(Dense(256, 'relu'))
model.add(Dropout(0.2))

model.add(Dense(128, 'relu'))
model.add(Dropout(0.2))

model.add(Dense(64, 'relu'))
model.add(Dropout(0.2))

model.add(Dense(10, 'softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=20, validation_split=0.2)
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8096 - loss: 0.5967 - val_accuracy: 0.9591 - val_loss: 0.1339
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9547 - loss: 0.1602 - val_accuracy: 0.9628 - val_loss: 0.1193
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9658 - loss: 0.1175 - val_accuracy: 0.9718 - val_loss: 0.0963
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9723 - loss: 0.0948 - val_accuracy: 0.9747 - val_loss: 0.0907
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9741 - loss: 0.0879 - val_accuracy: 0.9747 - val_loss: 0.0940
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9768 - loss: 0.0782 - val_accuracy: 0.9710 - val_loss: 0.1022
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9802 - loss: 0.0669 - val_accuracy: 0.9775 - val_loss: 0.0855
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9807 - loss: 0.0616 - val_accuracy: 0.9768 - val_loss: 0.0862
# Epoch 9/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9833 - loss: 0.0541 - val_accuracy: 0.9778 - val_loss: 0.0909
# Epoch 10/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9835 - loss: 0.0537 - val_accuracy: 0.9774 - val_loss: 0.0876
# Epoch 11/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9852 - loss: 0.0480 - val_accuracy: 0.9769 - val_loss: 0.0949
# Epoch 12/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9854 - loss: 0.0483 - val_accuracy: 0.9785 - val_loss: 0.0907
# Epoch 13/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9876 - loss: 0.0414 - val_accuracy: 0.9755 - val_loss: 0.1050
# Epoch 14/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9889 - loss: 0.0367 - val_accuracy: 0.9793 - val_loss: 0.0964
# Epoch 15/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9887 - loss: 0.0389 - val_accuracy: 0.9778 - val_loss: 0.1003
# Epoch 16/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9880 - loss: 0.0366 - val_accuracy: 0.9798 - val_loss: 0.0967
# Epoch 17/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9904 - loss: 0.0301 - val_accuracy: 0.9781 - val_loss: 0.0986
# Epoch 18/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9900 - loss: 0.0332 - val_accuracy: 0.9774 - val_loss: 0.1059
# Epoch 19/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9891 - loss: 0.0337 - val_accuracy: 0.9783 - val_loss: 0.1082
# Epoch 20/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9906 - loss: 0.0322 - val_accuracy: 0.9779 - val_loss: 0.1136

# %% [markdown]
# ### Results

# %%
plt.plot(history.history['accuracy'][0:], label='Train Accuracy')
plt.plot(history.history['val_accuracy'][0:], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')
plt.show()

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9788 - loss: 0.0989
# [0.08355319499969482, 0.9818999767303467]

# %% [markdown]
# We can see that such a model gave substanially better results with upto 98% test accuracy only after 5 epochs of training, however after that model overfits

# %% [markdown]
# ## Conclusion
# We have tried very complex models already to no avail. Now we move on to CNNs which can acheive higher accuracies in simpler models

# %% [markdown]
# ## Convolutional Neural Networks
#
# Let's try a simple CNN on our dataset

# %% [markdown]
# ### Building and training

# %% [markdown]
# Reshaping data for CNN

# %%
x_train, y_train = x_train.reshape(60000, 28,28,1) , y_train#.reshape(60000, 1)
x_test, y_test = x_test.reshape(10000, 28,28,1) , y_test#.reshape(10000, 1)

# %% [markdown]
# CNN Model

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D #type:ignore
from tensorflow.keras.callbacks import EarlyStopping

# %%
model = Sequential()

#model.add(Input(shape=(28,28,1)))

model.add(Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.1))

model.add(Conv2D(32, (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.1))

model.add(Flatten())
model.add(Dense(32, 'relu'))
model.add(Dropout(0.2))
model.add(Dense(10, 'softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_accuracy', patience=7, restore_best_weights=True)

# %%
history = model.fit(x_train, y_train, validation_split=0.2, epochs=20, callbacks=[early_stopping])
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7661 - loss: 0.7001 - val_accuracy: 0.9754 - val_loss: 0.0848
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9529 - loss: 0.1524 - val_accuracy: 0.9812 - val_loss: 0.0618
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9672 - loss: 0.1063 - val_accuracy: 0.9842 - val_loss: 0.0565
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9729 - loss: 0.0855 - val_accuracy: 0.9855 - val_loss: 0.0523
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9759 - loss: 0.0757 - val_accuracy: 0.9875 - val_loss: 0.0460
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9804 - loss: 0.0644 - val_accuracy: 0.9879 - val_loss: 0.0443
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9817 - loss: 0.0575 - val_accuracy: 0.9889 - val_loss: 0.0446
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9829 - loss: 0.0551 - val_accuracy: 0.9896 - val_loss: 0.0406
# Epoch 9/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9829 - loss: 0.0543 - val_accuracy: 0.9908 - val_loss: 0.0389
# Epoch 10/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9842 - loss: 0.0470 - val_accuracy: 0.9884 - val_loss: 0.0412
# Epoch 11/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9854 - loss: 0.0466 - val_accuracy: 0.9899 - val_loss: 0.0399
# Epoch 12/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9862 - loss: 0.0406 - val_accuracy: 0.9911 - val_loss: 0.0353
# Epoch 13/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9871 - loss: 0.0394 - val_accuracy: 0.9901 - val_loss: 0.0394
# Epoch 14/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9876 - loss: 0.0375 - val_accuracy: 0.9904 - val_loss: 0.0406
# Epoch 15/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9875 - loss: 0.0362 - val_accuracy: 0.9906 - val_loss: 0.0356
# Epoch 16/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9889 - loss: 0.0336 - val_accuracy: 0.9916 - val_loss: 0.0365
# Epoch 17/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9884 - loss: 0.0357 - val_accuracy: 0.9912 - val_loss: 0.0364
# Epoch 18/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9906 - loss: 0.0312 - val_accuracy: 0.9910 - val_loss: 0.0364
# Epoch 19/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9892 - loss: 0.0322 - val_accuracy: 0.9903 - val_loss: 0.0362
# Epoch 20/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9907 - loss: 0.0295 - val_accuracy: 0.9917 - val_loss: 0.0366

# %% [markdown]
# ### Results

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9908 - loss: 0.0262
# [0.02286999113857746, 0.9926000237464905]

# %%
plt.plot(history.history['accuracy'][0:], label='Train Accuracy')
plt.plot(history.history['val_accuracy'][0:], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# CNN gives, about same or higher result metrics for much less training times and simpler model
